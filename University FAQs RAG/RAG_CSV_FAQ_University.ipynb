# %% [markdown]
# **RAG Implementation**

# %%
# !pip install langchain pinecone-client google-generativeai openai tqdm chromadb langchain_community langchain-google-genai --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 3.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.8/244.8 kB 9.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 605.5/605.5 kB 22.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 59.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 61.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 41.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.6/278.6 kB 17.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.8/94.8 kB 6.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 58.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 411.6/411.6 kB 20.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.2/93.2 kB 6.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 78.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.4/85.4 kB 5.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.9/54.9 kB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.7/319.7 kB 16.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.1/442.1 kB 24.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 kB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.2/73.2 kB 4.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 58.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 443.8/443.8 kB 23.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 5.9 MB/s eta 0:00:00
#   Building wheel for pypika (pyproject.toml) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.17.1 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 5.29.2 which is incompatible.
# tensorflow-metadata 1.13.1 requires protobuf<5,>=3.20.3, but you have protobuf 5.29.2 which is incompatible.

# %%
# Step 2: Import Required Modules
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_google_genai import GoogleGenerativeAIEmbeddings
from langchain.chains import create_retrieval_chain
from langchain.vectorstores import Chroma
from langchain.document_loaders import CSVLoader
from langchain.prompts import PromptTemplate

# %%
# Step 3: Download the dataset and load it locally
import requests

path = '/content/faq_bot_university.csv'
# changed line
loader = CSVLoader(file_path=path, source_column='Answer')
documents = loader.load()

# %%
documents
# Out:
# [Document(metadata={'source': 'The tuition fee for undergraduate programs is $15,000 per year.', 'row': 0}, page_content='Question: What is the tuition fee for undergraduate programs?\nAnswer: The tuition fee for undergraduate programs is $15,000 per year.'),
#  Document(metadata={'source': 'The admission deadline is April 30.', 'row': 1}, page_content='Question: When is the admission deadline?\nAnswer: The admission deadline is April 30.'),
#  Document(metadata={'source': 'Courses include AI, Data Science, and Web Development.', 'row': 2}, page_content='Question: What courses are offered in Computer Science?\nAnswer: Courses include AI, Data Science, and Web Development.'),
#  Document(metadata={'source': 'Yes, international students can apply for financial aid.', 'row': 3}, page_content='Question: Can international students apply for financial aid?\nAnswer: Yes, international students can apply for financial aid.'),
#  Document(metadata={'source': 'Yes, on-campus housing is available for all students.', 'row': 4}, page_content='Question: Is there on-campus housing available?\nAnswer: Yes, on-campus housing is available for all students.'),
#  Document(metadata={'source': 'The tuition fee for undergraduate programs is $15,000 per year.', 'row': 5}, page_content='Question: What is the tuition fee for undergraduate programs?\nAnswer: The tuition fee for undergraduate programs is $15,000 per year.'),
#  Document(metadata={'source': 'The admission deadline is April 30.', 'row': 6}, page_content='Question: When is the admission deadline?\nAnswer: The admission deadline is April 30.'),
#  Document(metadata={'source': 'Courses include AI, Data Science, and Web Development.', 'row': 7}, page_content='Question: What courses are offered in Computer Science?\nAnswer: Courses include AI, Data Science, and Web Development.'),
#  Document(metadata={'source': 'Yes, international students can apply for financial aid.', 'row': 8}, page_content='Question: Can international students apply for financial aid?\nAnswer: Yes, international students can apply for financial aid.'),
#  Document(metadata={'source': 'Yes, on-campus housing is available for all students.', 'row': 9}, page_content='Question: Is there on-campus housing available?\nAnswer: Yes, on-campus housing is available for all students.'),
#  Document(metadata={'source': 'The tuition fee for undergraduate programs is $15,000 per year.', 'row': 10}, page_content='Question: What is the tuition fee for undergraduate programs?\nAnswer: The tuition fee for undergraduate programs is $15,000 per year.'),
#  Document(metadata={'source': 'The admission deadline is April 30.', 'row': 11}, page_content='Question: When is the admission deadline?\nAnswer: The admission deadline is April 30.'),
#  Document(metadata={'source': 'Courses include AI, Data Science, and Web Development.', 'row': 12}, page_content='Question: What courses are offered in Computer Science?\nAnswer: Courses include AI, Data Science, and Web Development.'),
#  Document(metadata={'source': 'Yes, international students can apply for financial aid.', 'row': 13}, page_content='Question: Can international students apply for financial aid?\nAnswer: Yes, international students can apply for financial aid.'),
#  Document(metadata={'source': 'Yes, on-campus housing is available for all students.', 'row': 14}, page_content='Question: Is there on-campus housing available?\nAnswer: Yes, on-campus housing is available for all students.'),
#  Document(metadata={'source': 'The tuition fee for undergraduate programs is $15,000 per year.', 'row': 15}, page_content='Question: What is the tuition fee for undergraduate programs?\nAnswer: The tuition fee for undergraduate programs is $15,000 per year.'),
#  Document(metadata={'source': 'The admission deadline is April 30.', 'row': 16}, page_content='Question: When is the admission deadline?\nAnswer: The admission deadline is April 30.'),
#  Document(metadata={'source': 'Courses include AI, Data Science, and Web Development.', 'row': 17}, page_content='Question: What courses are offered in Computer Science?\nAnswer: Courses include AI, Data Science, and Web Development.'),
#  Document(metadata={'source': 'Yes, international students can apply for financial aid.', 'row': 18}, page_content='Question: Can international students apply for financial aid?\nAnswer: Yes, international students can apply for financial aid.'),
#  Document(metadata={'source': 'Yes, on-campus housing is available for all students.', 'row': 19}, page_content='Question: Is there on-campus housing available?\nAnswer: Yes, on-campus housing is available for all students.'),
#  Document(metadata={'source': 'The tuition fee for undergraduate programs is $15,000 per year.', 'row': 20}, page_content='Question: What is the tuition fee for undergraduate programs?\nAnswer: The tuition fee for undergraduate programs is $15,000 per year.'),
#  Document(metadata={'source': 'The admission deadline is April 30.', 'row': 21}, page_content='Question: When is the admission deadline?\nAnswer: The admission deadline is April 30.'),
#  Document(metadata={'source': 'Courses include AI, Data Science, and Web Development.', 'row': 22}, page_content='Question: What courses are offered in Computer Science?\nAnswer: Courses include AI, Data Science, and Web Development.'),
#  Document(metadata={'source': 'Yes, international students can apply for financial aid.', 'row': 23}, page_content='Question: Can international students apply for financial aid?\nAnswer: Yes, international students can apply for financial aid.'),
#  Document(metadata={'source': 'Yes, on-campus housing is available for all students.', 'row': 24}, page_content='Question: Is there on-campus housing available?\nAnswer: Yes, on-campus housing is available for all students.'),
#  Document(metadata={'source': 'The tuition fee for undergraduate programs is $15,000 per year.', 'row': 25}, page_content='Question: What is the tuition fee for undergraduate programs?\nAnswer: The tuition fee for undergraduate programs is $15,000 per year.'),
#  Document(metadata={'source': 'The admission deadline is April 30.', 'row': 26}, page_content='Question: When is the admission deadline?\nAnswer: The admission deadline is April 30.'),
#  Document(metadata={'source': 'Courses include AI, Data Science, and Web Development.', 'row': 27}, page_content='Question: What courses are offered in Computer Science?\nAnswer: Courses include AI, Data Science, and Web Development.'),
#  Document(metadata={'source': 'Yes, international students can apply for financial aid.', 'row': 28}, page_content='Question: Can international students apply for financial aid?\nAnswer: Yes, international students can apply for financial aid.'),
#  Document(metadata={'source': 'Yes, on-campus housing is available for all students.', 'row': 29}, page_content='Question: Is there on-campus housing available?\nAnswer: Yes, on-campus housing is available for all students.'),
#  Document(metadata={'source': 'The tuition fee for undergraduate programs is $15,000 per year.', 'row': 30}, page_content='Question: What is the tuition fee for undergraduate programs?\nAnswer: The tuition fee for undergraduate programs is $15,000 per year.'),
#  Document(metadata={'source': 'The admission deadline is April 30.', 'row': 31}, page_content='Question: When is the admission deadline?\nAnswer: The admission deadline is April 30.'),
#  Document(metadata={'source': 'Courses include AI, Data Science, and Web Development.', 'row': 32}, page_content='Question: What courses are offered in Computer Science?\nAnswer: Courses include AI, Data Science, and Web Development.'),
#  Document(metadata={'source': 'Yes, international students can apply for financial aid.', 'row': 33}, page_content='Question: Can international students apply for financial aid?\nAnswer: Yes, international students can apply for financial aid.'),
#  Document(metadata={'source': 'Yes, on-campus housing is available for all students.', 'row': 34}, page_content='Question: Is there on-campus housing available?\nAnswer: Yes, on-campus housing is available for all students.'),
#  Document(metadata={'source': 'The tuition fee for undergraduate programs is $15,000 per year.', 'row': 35}, page_content='Question: What is the tuition fee for undergraduate programs?\nAnswer: The tuition fee for undergraduate programs is $15,000 per year.'),
#  Document(metadata={'source': 'The admission deadline is April 30.', 'row': 36}, page_content='Question: When is the admission deadline?\nAnswer: The admission deadline is April 30.'),
#  Document(metadata={'source': 'Courses include AI, Data Science, and Web Development.', 'row': 37}, page_content='Question: What courses are offered in Computer Science?\nAnswer: Courses include AI, Data Science, and Web Development.'),
#  Document(metadata={'source': 'Yes, international students can apply for financial aid.', 'row': 38}, page_content='Question: Can international students apply for financial aid?\nAnswer: Yes, international students can apply for financial aid.'),
#  Document(metadata={'source': 'Yes, on-campus housing is available for all students.', 'row': 39}, page_content='Question: Is there on-campus housing available?\nAnswer: Yes, on-campus housing is available for all students.'),
#  Document(metadata={'source': 'The tuition fee for undergraduate programs is $15,000 per year.', 'row': 40}, page_content='Question: What is the tuition fee for undergraduate programs?\nAnswer: The tuition fee for undergraduate programs is $15,000 per year.'),
#  Document(metadata={'source': 'The admission deadline is April 30.', 'row': 41}, page_content='Question: When is the admission deadline?\nAnswer: The admission deadline is April 30.'),
#  Document(metadata={'source': 'Courses include AI, Data Science, and Web Development.', 'row': 42}, page_content='Question: What courses are offered in Computer Science?\nAnswer: Courses include AI, Data Science, and Web Development.'),
#  Document(metadata={'source': 'Yes, international students can apply for financial aid.', 'row': 43}, page_content='Question: Can international students apply for financial aid?\nAnswer: Yes, international students can apply for financial aid.'),
#  Document(metadata={'source': 'Yes, on-campus housing is available for all students.', 'row': 44}, page_content='Question: Is there on-campus housing available?\nAnswer: Yes, on-campus housing is available for all students.'),
#  Document(metadata={'source': 'The tuition fee for undergraduate programs is $15,000 per year.', 'row': 45}, page_content='Question: What is the tuition fee for undergraduate programs?\nAnswer: The tuition fee for undergraduate programs is $15,000 per year.'),
#  Document(metadata={'source': 'The admission deadline is April 30.', 'row': 46}, page_content='Question: When is the admission deadline?\nAnswer: The admission deadline is April 30.'),
#  Document(metadata={'source': 'Courses include AI, Data Science, and Web Development.', 'row': 47}, page_content='Question: What courses are offered in Computer Science?\nAnswer: Courses include AI, Data Science, and Web Development.'),
#  Document(metadata={'source': 'Yes, international students can apply for financial aid.', 'row': 48}, page_content='Question: Can international students apply for financial aid?\nAnswer: Yes, international students can apply for financial aid.'),
#  Document(metadata={'source': 'Yes, on-campus housing is available for all students.', 'row': 49}, page_content='Question: Is there on-campus housing available?\nAnswer: Yes, on-campus housing is available for all students.'),
#  Document(metadata={'source': 'The tuition fee for undergraduate programs is $15,000 per year.', 'row': 50}, page_content='Question: What is the tuition fee for undergraduate programs?\nAnswer: The tuition fee for undergraduate programs is $15,000 per year.'),
#  Document(metadata={'source': 'The admission deadline is April 30.', 'row': 51}, page_content='Question: When is the admission deadline?\nAnswer: The admission deadline is April 30.'),
#  Document(metadata={'source': 'Courses include AI, Data Science, and Web Development.', 'row': 52}, page_content='Question: What courses are offered in Computer Science?\nAnswer: Courses include AI, Data Science, and Web Development.'),
#  Document(metadata={'source': 'Yes, international students can apply for financial aid.', 'row': 53}, page_content='Question: Can international students apply for financial aid?\nAnswer: Yes, international students can apply for financial aid.'),
#  Document(metadata={'source': 'Yes, on-campus housing is available for all students.', 'row': 54}, page_content='Question: Is there on-campus housing available?\nAnswer: Yes, on-campus housing is available for all students.'),
#  Document(metadata={'source': 'The tuition fee for undergraduate programs is $15,000 per year.', 'row': 55}, page_content='Question: What is the tuition fee for undergraduate programs?\nAnswer: The tuition fee for undergraduate programs is $15,000 per year.'),
#  Document(metadata={'source': 'The admission deadline is April 30.', 'row': 56}, page_content='Question: When is the admission deadline?\nAnswer: The admission deadline is April 30.'),
#  Document(metadata={'source': 'Courses include AI, Data Science, and Web Development.', 'row': 57}, page_content='Question: What courses are offered in Computer Science?\nAnswer: Courses include AI, Data Science, and Web Development.'),
#  Document(metadata={'source': 'Yes, international students can apply for financial aid.', 'row': 58}, page_content='Question: Can international students apply for financial aid?\nAnswer: Yes, international students can apply for financial aid.'),
#  Document(metadata={'source': 'Yes, on-campus housing is available for all students.', 'row': 59}, page_content='Question: Is there on-campus housing available?\nAnswer: Yes, on-campus housing is available for all students.'),
#  Document(metadata={'source': 'The tuition fee for undergraduate programs is $15,000 per year.', 'row': 60}, page_content='Question: What is the tuition fee for undergraduate programs?\nAnswer: The tuition fee for undergraduate programs is $15,000 per year.'),
#  Document(metadata={'source': 'The admission deadline is April 30.', 'row': 61}, page_content='Question: When is the admission deadline?\nAnswer: The admission deadline is April 30.'),
#  Document(metadata={'source': 'Courses include AI, Data Science, and Web Development.', 'row': 62}, page_content='Question: What courses are offered in Computer Science?\nAnswer: Courses include AI, Data Science, and Web Development.'),
#  Document(metadata={'source': 'Yes, international students can apply for financial aid.', 'row': 63}, page_content='Question: Can international students apply for financial aid?\nAnswer: Yes, international students can apply for financial aid.'),
#  Document(metadata={'source': 'Yes, on-campus housing is available for all students.', 'row': 64}, page_content='Question: Is there on-campus housing available?\nAnswer: Yes, on-campus housing is available for all students.'),
#  Document(metadata={'source': 'The tuition fee for undergraduate programs is $15,000 per year.', 'row': 65}, page_content='Question: What is the tuition fee for undergraduate programs?\nAnswer: The tuition fee for undergraduate programs is $15,000 per year.'),
#  Document(metadata={'source': 'The admission deadline is April 30.', 'row': 66}, page_content='Question: When is the admission deadline?\nAnswer: The admission deadline is April 30.'),
#  Document(metadata={'source': 'Courses include AI, Data Science, and Web Development.', 'row': 67}, page_content='Question: What courses are offered in Computer Science?\nAnswer: Courses include AI, Data Science, and Web Development.'),
#  Document(metadata={'source': 'Yes, international students can apply for financial aid.', 'row': 68}, page_content='Question: Can international students apply for financial aid?\nAnswer: Yes, international students can apply for financial aid.'),
#  Document(metadata={'source': 'Yes, on-campus housing is available for all students.', 'row': 69}, page_content='Question: Is there on-campus housing available?\nAnswer: Yes, on-campus housing is available for all students.'),
#  Document(metadata={'source': 'The tuition fee for undergraduate programs is $15,000 per year.', 'row': 70}, page_content='Question: What is the tuition fee for undergraduate programs?\nAnswer: The tuition fee for undergraduate programs is $15,000 per year.'),
#  Document(metadata={'source': 'The admission deadline is April 30.', 'row': 71}, page_content='Question: When is the admission deadline?\nAnswer: The admission deadline is April 30.'),
#  Document(metadata={'source': 'Courses include AI, Data Science, and Web Development.', 'row': 72}, page_content='Question: What courses are offered in Computer Science?\nAnswer: Courses include AI, Data Science, and Web Development.'),
#  Document(metadata={'source': 'Yes, international students can apply for financial aid.', 'row': 73}, page_content='Question: Can international students apply for financial aid?\nAnswer: Yes, international students can apply for financial aid.'),
#  Document(metadata={'source': 'Yes, on-campus housing is available for all students.', 'row': 74}, page_content='Question: Is there on-campus housing available?\nAnswer: Yes, on-campus housing is available for all students.'),
#  Document(metadata={'source': 'The tuition fee for undergraduate programs is $15,000 per year.', 'row': 75}, page_content='Question: What is the tuition fee for undergraduate programs?\nAnswer: The tuition fee for undergraduate programs is $15,000 per year.'),
#  Document(metadata={'source': 'The admission deadline is April 30.', 'row': 76}, page_content='Question: When is the admission deadline?\nAnswer: The admission deadline is April 30.'),
#  Document(metadata={'source': 'Courses include AI, Data Science, and Web Development.', 'row': 77}, page_content='Question: What courses are offered in Computer Science?\nAnswer: Courses include AI, Data Science, and Web Development.'),
#  Document(metadata={'source': 'Yes, international students can apply for financial aid.', 'row': 78}, page_content='Question: Can international students apply for financial aid?\nAnswer: Yes, international students can apply for financial aid.'),
#  Document(metadata={'source': 'Yes, on-campus housing is available for all students.', 'row': 79}, page_content='Question: Is there on-campus housing available?\nAnswer: Yes, on-campus housing is available for all students.'),
#  Document(metadata={'source': 'The tuition fee for undergraduate programs is $15,000 per year.', 'row': 80}, page_content='Question: What is the tuition fee for undergraduate programs?\nAnswer: The tuition fee for undergraduate programs is $15,000 per year.'),
#  Document(metadata={'source': 'The admission deadline is April 30.', 'row': 81}, page_content='Question: When is the admission deadline?\nAnswer: The admission deadline is April 30.'),
#  Document(metadata={'source': 'Courses include AI, Data Science, and Web Development.', 'row': 82}, page_content='Question: What courses are offered in Computer Science?\nAnswer: Courses include AI, Data Science, and Web Development.'),
#  Document(metadata={'source': 'Yes, international students can apply for financial aid.', 'row': 83}, page_content='Question: Can international students apply for financial aid?\nAnswer: Yes, international students can apply for financial aid.'),
#  Document(metadata={'source': 'Yes, on-campus housing is available for all students.', 'row': 84}, page_content='Question: Is there on-campus housing available?\nAnswer: Yes, on-campus housing is available for all students.'),
#  Document(metadata={'source': 'The tuition fee for undergraduate programs is $15,000 per year.', 'row': 85}, page_content='Question: What is the tuition fee for undergraduate programs?\nAnswer: The tuition fee for undergraduate programs is $15,000 per year.'),
#  Document(metadata={'source': 'The admission deadline is April 30.', 'row': 86}, page_content='Question: When is the admission deadline?\nAnswer: The admission deadline is April 30.'),
#  Document(metadata={'source': 'Courses include AI, Data Science, and Web Development.', 'row': 87}, page_content='Question: What courses are offered in Computer Science?\nAnswer: Courses include AI, Data Science, and Web Development.'),
#  Document(metadata={'source': 'Yes, international students can apply for financial aid.', 'row': 88}, page_content='Question: Can international students apply for financial aid?\nAnswer: Yes, international students can apply for financial aid.'),
#  Document(metadata={'source': 'Yes, on-campus housing is available for all students.', 'row': 89}, page_content='Question: Is there on-campus housing available?\nAnswer: Yes, on-campus housing is available for all students.'),
#  Document(metadata={'source': 'The tuition fee for undergraduate programs is $15,000 per year.', 'row': 90}, page_content='Question: What is the tuition fee for undergraduate programs?\nAnswer: The tuition fee for undergraduate programs is $15,000 per year.'),
#  Document(metadata={'source': 'The admission deadline is April 30.', 'row': 91}, page_content='Question: When is the admission deadline?\nAnswer: The admission deadline is April 30.'),
#  Document(metadata={'source': 'Courses include AI, Data Science, and Web Development.', 'row': 92}, page_content='Question: What courses are offered in Computer Science?\nAnswer: Courses include AI, Data Science, and Web Development.'),
#  Document(metadata={'source': 'Yes, international students can apply for financial aid.', 'row': 93}, page_content='Question: Can international students apply for financial aid?\nAnswer: Yes, international students can apply for financial aid.'),
#  Document(metadata={'source': 'Yes, on-campus housing is available for all students.', 'row': 94}, page_content='Question: Is there on-campus housing available?\nAnswer: Yes, on-campus housing is available for all students.'),
#  Document(metadata={'source': 'The tuition fee for undergraduate programs is $15,000 per year.', 'row': 95}, page_content='Question: What is the tuition fee for undergraduate programs?\nAnswer: The tuition fee for undergraduate programs is $15,000 per year.'),
#  Document(metadata={'source': 'The admission deadline is April 30.', 'row': 96}, page_content='Question: When is the admission deadline?\nAnswer: The admission deadline is April 30.'),
#  Document(metadata={'source': 'Courses include AI, Data Science, and Web Development.', 'row': 97}, page_content='Question: What courses are offered in Computer Science?\nAnswer: Courses include AI, Data Science, and Web Development.'),
#  Document(metadata={'source': 'Yes, international students can apply for financial aid.', 'row': 98}, page_content='Question: Can international students apply for financial aid?\nAnswer: Yes, international students can apply for financial aid.'),
#  Document(metadata={'source': 'Yes, on-campus housing is available for all students.', 'row': 99}, page_content='Question: Is there on-campus housing available?\nAnswer: Yes, on-campus housing is available for all students.'),
#  Document(metadata={'source': 'The tuition fee for undergraduate programs is $15,000 per year.', 'row': 100}, page_content='Question: What is the tuition fee for undergraduate programs?\nAnswer: The tuition fee for undergraduate programs is $15,000 per year.'),
#  Document(metadata={'source': 'The admission deadline is April 30.', 'row': 101}, page_content='Question: When is the admission deadline?\nAnswer: The admission deadline is April 30.'),
#  Document(metadata={'source': 'Courses include AI, Data Science, and Web Development.', 'row': 102}, page_content='Question: What courses are offered in Computer Science?\nAnswer: Courses include AI, Data Science, and Web Development.'),
#  Document(metadata={'source': 'Yes, international students can apply for financial aid.', 'row': 103}, page_content='Question: Can international students apply for financial aid?\nAnswer: Yes, international students can apply for financial aid.'),
#  Document(metadata={'source': 'Yes, on-campus housing is available for all students.', 'row': 104}, page_content='Question: Is there on-campus housing available?\nAnswer: Yes, on-campus housing is available for all students.'),
#  Document(metadata={'source': 'The tuition fee for undergraduate programs is $15,000 per year.', 'row': 105}, page_content='Question: What is the tuition fee for undergraduate programs?\nAnswer: The tuition fee for undergraduate programs is $15,000 per year.'),
#  Document(metadata={'source': 'The admission deadline is April 30.', 'row': 106}, page_content='Question: When is the admission deadline?\nAnswer: The admission deadline is April 30.'),
#  Document(metadata={'source': 'Courses include AI, Data Science, and Web Development.', 'row': 107}, page_content='Question: What courses are offered in Computer Science?\nAnswer: Courses include AI, Data Science, and Web Development.'),
#  Document(metadata={'source': 'Yes, international students can apply for financial aid.', 'row': 108}, page_content='Question: Can international students apply for financial aid?\nAnswer: Yes, international students can apply for financial aid.'),
#  Document(metadata={'source': 'Yes, on-campus housing is available for all students.', 'row': 109}, page_content='Question: Is there on-campus housing available?\nAnswer: Yes, on-campus housing is available for all students.'),
#  Document(metadata={'source': 'The tuition fee for undergraduate programs is $15,000 per year.', 'row': 110}, page_content='Question: What is the tuition fee for undergraduate programs?\nAnswer: The tuition fee for undergraduate programs is $15,000 per year.'),
#  Document(metadata={'source': 'The admission deadline is April 30.', 'row': 111}, page_content='Question: When is the admission deadline?\nAnswer: The admission deadline is April 30.'),
#  Document(metadata={'source': 'Courses include AI, Data Science, and Web Development.', 'row': 112}, page_content='Question: What courses are offered in Computer Science?\nAnswer: Courses include AI, Data Science, and Web Development.'),
#  Document(metadata={'source': 'Yes, international students can apply for financial aid.', 'row': 113}, page_content='Question: Can international students apply for financial aid?\nAnswer: Yes, international students can apply for financial aid.'),
#  Document(metadata={'source': 'Yes, on-campus housing is available for all students.', 'row': 114}, page_content='Question: Is there on-campus housing available?\nAnswer: Yes, on-campus housing is available for all students.'),
#  Document(metadata={'source': 'The tuition fee for undergraduate programs is $15,000 per year.', 'row': 115}, page_content='Question: What is the tuition fee for undergraduate programs?\nAnswer: The tuition fee for undergraduate programs is $15,000 per year.'),
#  Document(metadata={'source': 'The admission deadline is April 30.', 'row': 116}, page_content='Question: When is the admission deadline?\nAnswer: The admission deadline is April 30.'),
#  Document(metadata={'source': 'Courses include AI, Data Science, and Web Development.', 'row': 117}, page_content='Question: What courses are offered in Computer Science?\nAnswer: Courses include AI, Data Science, and Web Development.'),
#  Document(metadata={'source': 'Yes, international students can apply for financial aid.', 'row': 118}, page_content='Question: Can international students apply for financial aid?\nAnswer: Yes, international students can apply for financial aid.'),
#  Document(metadata={'source': 'Yes, on-campus housing is available for all students.', 'row': 119}, page_content='Question: Is there on-campus housing available?\nAnswer: Yes, on-campus housing is available for all students.'),
#  Document(metadata={'source': 'The tuition fee for undergraduate programs is $15,000 per year.', 'row': 120}, page_content='Question: What is the tuition fee for undergraduate programs?\nAnswer: The tuition fee for undergraduate programs is $15,000 per year.'),
#  Document(metadata={'source': 'The admission deadline is April 30.', 'row': 121}, page_content='Question: When is the admission deadline?\nAnswer: The admission deadline is April 30.'),
#  Document(metadata={'source': 'Courses include AI, Data Science, and Web Development.', 'row': 122}, page_content='Question: What courses are offered in Computer Science?\nAnswer: Courses include AI, Data Science, and Web Development.'),
#  Document(metadata={'source': 'Yes, international students can apply for financial aid.', 'row': 123}, page_content='Question: Can international students apply for financial aid?\nAnswer: Yes, international students can apply for financial aid.'),
#  Document(metadata={'source': 'Yes, on-campus housing is available for all students.', 'row': 124}, page_content='Question: Is there on-campus housing available?\nAnswer: Yes, on-campus housing is available for all students.'),
#  Document(metadata={'source': 'The tuition fee for undergraduate programs is $15,000 per year.', 'row': 125}, page_content='Question: What is the tuition fee for undergraduate programs?\nAnswer: The tuition fee for undergraduate programs is $15,000 per year.'),
#  Document(metadata={'source': 'The admission deadline is April 30.', 'row': 126}, page_content='Question: When is the admission deadline?\nAnswer: The admission deadline is April 30.'),
#  Document(metadata={'source': 'Courses include AI, Data Science, and Web Development.', 'row': 127}, page_content='Question: What courses are offered in Computer Science?\nAnswer: Courses include AI, Data Science, and Web Development.'),
#  Document(metadata={'source': 'Yes, international students can apply for financial aid.', 'row': 128}, page_content='Question: Can international students apply for financial aid?\nAnswer: Yes, international students can apply for financial aid.'),
#  Document(metadata={'source': 'Yes, on-campus housing is available for all students.', 'row': 129}, page_content='Question: Is there on-campus housing available?\nAnswer: Yes, on-campus housing is available for all students.'),
#  Document(metadata={'source': 'The tuition fee for undergraduate programs is $15,000 per year.', 'row': 130}, page_content='Question: What is the tuition fee for undergraduate programs?\nAnswer: The tuition fee for undergraduate programs is $15,000 per year.'),
#  Document(metadata={'source': 'The admission deadline is April 30.', 'row': 131}, page_content='Question: When is the admission deadline?\nAnswer: The admission deadline is April 30.'),
#  Document(metadata={'source': 'Courses include AI, Data Science, and Web Development.', 'row': 132}, page_content='Question: What courses are offered in Computer Science?\nAnswer: Courses include AI, Data Science, and Web Development.'),
#  Document(metadata={'source': 'Yes, international students can apply for financial aid.', 'row': 133}, page_content='Question: Can international students apply for financial aid?\nAnswer: Yes, international students can apply for financial aid.'),
#  Document(metadata={'source': 'Yes, on-campus housing is available for all students.', 'row': 134}, page_content='Question: Is there on-campus housing available?\nAnswer: Yes, on-campus housing is available for all students.'),
#  Document(metadata={'source': 'The tuition fee for undergraduate programs is $15,000 per year.', 'row': 135}, page_content='Question: What is the tuition fee for undergraduate programs?\nAnswer: The tuition fee for undergraduate programs is $15,000 per year.'),
#  Document(metadata={'source': 'The admission deadline is April 30.', 'row': 136}, page_content='Question: When is the admission deadline?\nAnswer: The admission deadline is April 30.'),
#  Document(metadata={'source': 'Courses include AI, Data Science, and Web Development.', 'row': 137}, page_content='Question: What courses are offered in Computer Science?\nAnswer: Courses include AI, Data Science, and Web Development.'),
#  Document(metadata={'source': 'Yes, international students can apply for financial aid.', 'row': 138}, page_content='Question: Can international students apply for financial aid?\nAnswer: Yes, international students can apply for financial aid.'),
#  Document(metadata={'source': 'Yes, on-campus housing is available for all students.', 'row': 139}, page_content='Question: Is there on-campus housing available?\nAnswer: Yes, on-campus housing is available for all students.'),
#  Document(metadata={'source': 'The tuition fee for undergraduate programs is $15,000 per year.', 'row': 140}, page_content='Question: What is the tuition fee for undergraduate programs?\nAnswer: The tuition fee for undergraduate programs is $15,000 per year.'),
#  Document(metadata={'source': 'The admission deadline is April 30.', 'row': 141}, page_content='Question: When is the admission deadline?\nAnswer: The admission deadline is April 30.'),
#  Document(metadata={'source': 'Courses include AI, Data Science, and Web Development.', 'row': 142}, page_content='Question: What courses are offered in Computer Science?\nAnswer: Courses include AI, Data Science, and Web Development.'),
#  Document(metadata={'source': 'Yes, international students can apply for financial aid.', 'row': 143}, page_content='Question: Can international students apply for financial aid?\nAnswer: Yes, international students can apply for financial aid.'),
#  Document(metadata={'source': 'Yes, on-campus housing is available for all students.', 'row': 144}, page_content='Question: Is there on-campus housing available?\nAnswer: Yes, on-campus housing is available for all students.'),
#  Document(metadata={'source': 'The tuition fee for undergraduate programs is $15,000 per year.', 'row': 145}, page_content='Question: What is the tuition fee for undergraduate programs?\nAnswer: The tuition fee for undergraduate programs is $15,000 per year.'),
#  Document(metadata={'source': 'The admission deadline is April 30.', 'row': 146}, page_content='Question: When is the admission deadline?\nAnswer: The admission deadline is April 30.'),
#  Document(metadata={'source': 'Courses include AI, Data Science, and Web Development.', 'row': 147}, page_content='Question: What courses are offered in Computer Science?\nAnswer: Courses include AI, Data Science, and Web Development.'),
#  Document(metadata={'source': 'Yes, international students can apply for financial aid.', 'row': 148}, page_content='Question: Can international students apply for financial aid?\nAnswer: Yes, international students can apply for financial aid.'),
#  Document(metadata={'source': 'Yes, on-campus housing is available for all students.', 'row': 149}, page_content='Question: Is there on-campus housing available?\nAnswer: Yes, on-campus housing is available for all students.'),
#  Document(metadata={'source': 'The tuition fee for undergraduate programs is $15,000 per year.', 'row': 150}, page_content='Question: What is the tuition fee for undergraduate programs?\nAnswer: The tuition fee for undergraduate programs is $15,000 per year.'),
#  Document(metadata={'source': 'The admission deadline is April 30.', 'row': 151}, page_content='Question: When is the admission deadline?\nAnswer: The admission deadline is April 30.'),
#  Document(metadata={'source': 'Courses include AI, Data Science, and Web Development.', 'row': 152}, page_content='Question: What courses are offered in Computer Science?\nAnswer: Courses include AI, Data Science, and Web Development.'),
#  Document(metadata={'source': 'Yes, international students can apply for financial aid.', 'row': 153}, page_content='Question: Can international students apply for financial aid?\nAnswer: Yes, international students can apply for financial aid.'),
#  Document(metadata={'source': 'Yes, on-campus housing is available for all students.', 'row': 154}, page_content='Question: Is there on-campus housing available?\nAnswer: Yes, on-campus housing is available for all students.'),
#  Document(metadata={'source': 'The tuition fee for undergraduate programs is $15,000 per year.', 'row': 155}, page_content='Question: What is the tuition fee for undergraduate programs?\nAnswer: The tuition fee for undergraduate programs is $15,000 per year.'),
#  Document(metadata={'source': 'The admission deadline is April 30.', 'row': 156}, page_content='Question: When is the admission deadline?\nAnswer: The admission deadline is April 30.'),
#  Document(metadata={'source': 'Courses include AI, Data Science, and Web Development.', 'row': 157}, page_content='Question: What courses are offered in Computer Science?\nAnswer: Courses include AI, Data Science, and Web Development.'),
#  Document(metadata={'source': 'Yes, international students can apply for financial aid.', 'row': 158}, page_content='Question: Can international students apply for financial aid?\nAnswer: Yes, international students can apply for financial aid.'),
#  Document(metadata={'source': 'Yes, on-campus housing is available for all students.', 'row': 159}, page_content='Question: Is there on-campus housing available?\nAnswer: Yes, on-campus housing is available for all students.'),
#  Document(metadata={'source': 'The tuition fee for undergraduate programs is $15,000 per year.', 'row': 160}, page_content='Question: What is the tuition fee for undergraduate programs?\nAnswer: The tuition fee for undergraduate programs is $15,000 per year.'),
#  Document(metadata={'source': 'The admission deadline is April 30.', 'row': 161}, page_content='Question: When is the admission deadline?\nAnswer: The admission deadline is April 30.'),
#  Document(metadata={'source': 'Courses include AI, Data Science, and Web Development.', 'row': 162}, page_content='Question: What courses are offered in Computer Science?\nAnswer: Courses include AI, Data Science, and Web Development.'),
#  Document(metadata={'source': 'Yes, international students can apply for financial aid.', 'row': 163}, page_content='Question: Can international students apply for financial aid?\nAnswer: Yes, international students can apply for financial aid.'),
#  Document(metadata={'source': 'Yes, on-campus housing is available for all students.', 'row': 164}, page_content='Question: Is there on-campus housing available?\nAnswer: Yes, on-campus housing is available for all students.'),
#  Document(metadata={'source': 'The tuition fee for undergraduate programs is $15,000 per year.', 'row': 165}, page_content='Question: What is the tuition fee for undergraduate programs?\nAnswer: The tuition fee for undergraduate programs is $15,000 per year.'),
#  Document(metadata={'source': 'The admission deadline is April 30.', 'row': 166}, page_content='Question: When is the admission deadline?\nAnswer: The admission deadline is April 30.'),
#  Document(metadata={'source': 'Courses include AI, Data Science, and Web Development.', 'row': 167}, page_content='Question: What courses are offered in Computer Science?\nAnswer: Courses include AI, Data Science, and Web Development.'),
#  Document(metadata={'source': 'Yes, international students can apply for financial aid.', 'row': 168}, page_content='Question: Can international students apply for financial aid?\nAnswer: Yes, international students can apply for financial aid.'),
#  Document(metadata={'source': 'Yes, on-campus housing is available for all students.', 'row': 169}, page_content='Question: Is there on-campus housing available?\nAnswer: Yes, on-campus housing is available for all students.'),
#  Document(metadata={'source': 'The tuition fee for undergraduate programs is $15,000 per year.', 'row': 170}, page_content='Question: What is the tuition fee for undergraduate programs?\nAnswer: The tuition fee for undergraduate programs is $15,000 per year.'),
#  Document(metadata={'source': 'The admission deadline is April 30.', 'row': 171}, page_content='Question: When is the admission deadline?\nAnswer: The admission deadline is April 30.'),
#  Document(metadata={'source': 'Courses include AI, Data Science, and Web Development.', 'row': 172}, page_content='Question: What courses are offered in Computer Science?\nAnswer: Courses include AI, Data Science, and Web Development.'),
#  Document(metadata={'source': 'Yes, international students can apply for financial aid.', 'row': 173}, page_content='Question: Can international students apply for financial aid?\nAnswer: Yes, international students can apply for financial aid.'),
#  Document(metadata={'source': 'Yes, on-campus housing is available for all students.', 'row': 174}, page_content='Question: Is there on-campus housing available?\nAnswer: Yes, on-campus housing is available for all students.'),
#  Document(metadata={'source': 'The tuition fee for undergraduate programs is $15,000 per year.', 'row': 175}, page_content='Question: What is the tuition fee for undergraduate programs?\nAnswer: The tuition fee for undergraduate programs is $15,000 per year.'),
#  Document(metadata={'source': 'The admission deadline is April 30.', 'row': 176}, page_content='Question: When is the admission deadline?\nAnswer: The admission deadline is April 30.'),
#  Document(metadata={'source': 'Courses include AI, Data Science, and Web Development.', 'row': 177}, page_content='Question: What courses are offered in Computer Science?\nAnswer: Courses include AI, Data Science, and Web Development.'),
#  Document(metadata={'source': 'Yes, international students can apply for financial aid.', 'row': 178}, page_content='Question: Can international students apply for financial aid?\nAnswer: Yes, international students can apply for financial aid.'),
#  Document(metadata={'source': 'Yes, on-campus housing is available for all students.', 'row': 179}, page_content='Question: Is there on-campus housing available?\nAnswer: Yes, on-campus housing is available for all students.'),
#  Document(metadata={'source': 'The tuition fee for undergraduate programs is $15,000 per year.', 'row': 180}, page_content='Question: What is the tuition fee for undergraduate programs?\nAnswer: The tuition fee for undergraduate programs is $15,000 per year.'),
#  Document(metadata={'source': 'The admission deadline is April 30.', 'row': 181}, page_content='Question: When is the admission deadline?\nAnswer: The admission deadline is April 30.'),
#  Document(metadata={'source': 'Courses include AI, Data Science, and Web Development.', 'row': 182}, page_content='Question: What courses are offered in Computer Science?\nAnswer: Courses include AI, Data Science, and Web Development.'),
#  Document(metadata={'source': 'Yes, international students can apply for financial aid.', 'row': 183}, page_content='Question: Can international students apply for financial aid?\nAnswer: Yes, international students can apply for financial aid.'),
#  Document(metadata={'source': 'Yes, on-campus housing is available for all students.', 'row': 184}, page_content='Question: Is there on-campus housing available?\nAnswer: Yes, on-campus housing is available for all students.'),
#  Document(metadata={'source': 'The tuition fee for undergraduate programs is $15,000 per year.', 'row': 185}, page_content='Question: What is the tuition fee for undergraduate programs?\nAnswer: The tuition fee for undergraduate programs is $15,000 per year.'),
#  Document(metadata={'source': 'The admission deadline is April 30.', 'row': 186}, page_content='Question: When is the admission deadline?\nAnswer: The admission deadline is April 30.'),
#  Document(metadata={'source': 'Courses include AI, Data Science, and Web Development.', 'row': 187}, page_content='Question: What courses are offered in Computer Science?\nAnswer: Courses include AI, Data Science, and Web Development.'),
#  Document(metadata={'source': 'Yes, international students can apply for financial aid.', 'row': 188}, page_content='Question: Can international students apply for financial aid?\nAnswer: Yes, international students can apply for financial aid.'),
#  Document(metadata={'source': 'Yes, on-campus housing is available for all students.', 'row': 189}, page_content='Question: Is there on-campus housing available?\nAnswer: Yes, on-campus housing is available for all students.'),
#  Document(metadata={'source': 'The tuition fee for undergraduate programs is $15,000 per year.', 'row': 190}, page_content='Question: What is the tuition fee for undergraduate programs?\nAnswer: The tuition fee for undergraduate programs is $15,000 per year.'),
#  Document(metadata={'source': 'The admission deadline is April 30.', 'row': 191}, page_content='Question: When is the admission deadline?\nAnswer: The admission deadline is April 30.'),
#  Document(metadata={'source': 'Courses include AI, Data Science, and Web Development.', 'row': 192}, page_content='Question: What courses are offered in Computer Science?\nAnswer: Courses include AI, Data Science, and Web Development.'),
#  Document(metadata={'source': 'Yes, international students can apply for financial aid.', 'row': 193}, page_content='Question: Can international students apply for financial aid?\nAnswer: Yes, international students can apply for financial aid.'),
#  Document(metadata={'source': 'Yes, on-campus housing is available for all students.', 'row': 194}, page_content='Question: Is there on-campus housing available?\nAnswer: Yes, on-campus housing is available for all students.'),
#  Document(metadata={'source': 'The tuition fee for undergraduate programs is $15,000 per year.', 'row': 195}, page_content='Question: What is the tuition fee for undergraduate programs?\nAnswer: The tuition fee for undergraduate programs is $15,000 per year.'),
#  Document(metadata={'source': 'The admission deadline is April 30.', 'row': 196}, page_content='Question: When is the admission deadline?\nAnswer: The admission deadline is April 30.'),
#  Document(metadata={'source': 'Courses include AI, Data Science, and Web Development.', 'row': 197}, page_content='Question: What courses are offered in Computer Science?\nAnswer: Courses include AI, Data Science, and Web Development.'),
#  Document(metadata={'source': 'Yes, international students can apply for financial aid.', 'row': 198}, page_content='Question: Can international students apply for financial aid?\nAnswer: Yes, international students can apply for financial aid.'),
#  Document(metadata={'source': 'Yes, on-campus housing is available for all students.', 'row': 199}, page_content='Question: Is there on-campus housing available?\nAnswer: Yes, on-campus housing is available for all students.'),
#  Document(metadata={'source': 'The tuition fee for undergraduate programs is $15,000 per year.', 'row': 200}, page_content='Question: What is the tuition fee for undergraduate programs?\nAnswer: The tuition fee for undergraduate programs is $15,000 per year.'),
#  Document(metadata={'source': 'The admission deadline is April 30.', 'row': 201}, page_content='Question: When is the admission deadline?\nAnswer: The admission deadline is April 30.'),
#  Document(metadata={'source': 'Courses include AI, Data Science, and Web Development.', 'row': 202}, page_content='Question: What courses are offered in Computer Science?\nAnswer: Courses include AI, Data Science, and Web Development.'),
#  Document(metadata={'source': 'Yes, international students can apply for financial aid.', 'row': 203}, page_content='Question: Can international students apply for financial aid?\nAnswer: Yes, international students can apply for financial aid.'),
#  Document(metadata={'source': 'Yes, on-campus housing is available for all students.', 'row': 204}, page_content='Question: Is there on-campus housing available?\nAnswer: Yes, on-campus housing is available for all students.'),
#  Document(metadata={'source': 'The tuition fee for undergraduate programs is $15,000 per year.', 'row': 205}, page_content='Question: What is the tuition fee for undergraduate programs?\nAnswer: The tuition fee for undergraduate programs is $15,000 per year.'),
#  Document(metadata={'source': 'The admission deadline is April 30.', 'row': 206}, page_content='Question: When is the admission deadline?\nAnswer: The admission deadline is April 30.'),
# ...
#  Document(metadata={'source': 'Courses include AI, Data Science, and Web Development.', 'row': 932}, page_content='Question: What courses are offered in Computer Science?\nAnswer: Courses include AI, Data Science, and Web Development.'),
#  Document(metadata={'source': 'Yes, international students can apply for financial aid.', 'row': 933}, page_content='Question: Can international students apply for financial aid?\nAnswer: Yes, international students can apply for financial aid.'),
#  Document(metadata={'source': 'Yes, on-campus housing is available for all students.', 'row': 934}, page_content='Question: Is there on-campus housing available?\nAnswer: Yes, on-campus housing is available for all students.'),
#  Document(metadata={'source': 'The tuition fee for undergraduate programs is $15,000 per year.', 'row': 935}, page_content='Question: What is the tuition fee for undergraduate programs?\nAnswer: The tuition fee for undergraduate programs is $15,000 per year.'),
#  Document(metadata={'source': 'The admission deadline is April 30.', 'row': 936}, page_content='Question: When is the admission deadline?\nAnswer: The admission deadline is April 30.'),
#  Document(metadata={'source': 'Courses include AI, Data Science, and Web Development.', 'row': 937}, page_content='Question: What courses are offered in Computer Science?\nAnswer: Courses include AI, Data Science, and Web Development.'),
#  Document(metadata={'source': 'Yes, international students can apply for financial aid.', 'row': 938}, page_content='Question: Can international students apply for financial aid?\nAnswer: Yes, international students can apply for financial aid.'),
#  Document(metadata={'source': 'Yes, on-campus housing is available for all students.', 'row': 939}, page_content='Question: Is there on-campus housing available?\nAnswer: Yes, on-campus housing is available for all students.'),
#  Document(metadata={'source': 'The tuition fee for undergraduate programs is $15,000 per year.', 'row': 940}, page_content='Question: What is the tuition fee for undergraduate programs?\nAnswer: The tuition fee for undergraduate programs is $15,000 per year.'),
#  Document(metadata={'source': 'The admission deadline is April 30.', 'row': 941}, page_content='Question: When is the admission deadline?\nAnswer: The admission deadline is April 30.'),
#  Document(metadata={'source': 'Courses include AI, Data Science, and Web Development.', 'row': 942}, page_content='Question: What courses are offered in Computer Science?\nAnswer: Courses include AI, Data Science, and Web Development.'),
#  Document(metadata={'source': 'Yes, international students can apply for financial aid.', 'row': 943}, page_content='Question: Can international students apply for financial aid?\nAnswer: Yes, international students can apply for financial aid.'),
#  Document(metadata={'source': 'Yes, on-campus housing is available for all students.', 'row': 944}, page_content='Question: Is there on-campus housing available?\nAnswer: Yes, on-campus housing is available for all students.'),
#  Document(metadata={'source': 'The tuition fee for undergraduate programs is $15,000 per year.', 'row': 945}, page_content='Question: What is the tuition fee for undergraduate programs?\nAnswer: The tuition fee for undergraduate programs is $15,000 per year.'),
#  Document(metadata={'source': 'The admission deadline is April 30.', 'row': 946}, page_content='Question: When is the admission deadline?\nAnswer: The admission deadline is April 30.'),
#  Document(metadata={'source': 'Courses include AI, Data Science, and Web Development.', 'row': 947}, page_content='Question: What courses are offered in Computer Science?\nAnswer: Courses include AI, Data Science, and Web Development.'),
#  Document(metadata={'source': 'Yes, international students can apply for financial aid.', 'row': 948}, page_content='Question: Can international students apply for financial aid?\nAnswer: Yes, international students can apply for financial aid.'),
#  Document(metadata={'source': 'Yes, on-campus housing is available for all students.', 'row': 949}, page_content='Question: Is there on-campus housing available?\nAnswer: Yes, on-campus housing is available for all students.'),
#  Document(metadata={'source': 'The tuition fee for undergraduate programs is $15,000 per year.', 'row': 950}, page_content='Question: What is the tuition fee for undergraduate programs?\nAnswer: The tuition fee for undergraduate programs is $15,000 per year.'),
#  Document(metadata={'source': 'The admission deadline is April 30.', 'row': 951}, page_content='Question: When is the admission deadline?\nAnswer: The admission deadline is April 30.'),
#  Document(metadata={'source': 'Courses include AI, Data Science, and Web Development.', 'row': 952}, page_content='Question: What courses are offered in Computer Science?\nAnswer: Courses include AI, Data Science, and Web Development.'),
#  Document(metadata={'source': 'Yes, international students can apply for financial aid.', 'row': 953}, page_content='Question: Can international students apply for financial aid?\nAnswer: Yes, international students can apply for financial aid.'),
#  Document(metadata={'source': 'Yes, on-campus housing is available for all students.', 'row': 954}, page_content='Question: Is there on-campus housing available?\nAnswer: Yes, on-campus housing is available for all students.'),
#  Document(metadata={'source': 'The tuition fee for undergraduate programs is $15,000 per year.', 'row': 955}, page_content='Question: What is the tuition fee for undergraduate programs?\nAnswer: The tuition fee for undergraduate programs is $15,000 per year.'),
#  Document(metadata={'source': 'The admission deadline is April 30.', 'row': 956}, page_content='Question: When is the admission deadline?\nAnswer: The admission deadline is April 30.'),
#  Document(metadata={'source': 'Courses include AI, Data Science, and Web Development.', 'row': 957}, page_content='Question: What courses are offered in Computer Science?\nAnswer: Courses include AI, Data Science, and Web Development.'),
#  Document(metadata={'source': 'Yes, international students can apply for financial aid.', 'row': 958}, page_content='Question: Can international students apply for financial aid?\nAnswer: Yes, international students can apply for financial aid.'),
#  Document(metadata={'source': 'Yes, on-campus housing is available for all students.', 'row': 959}, page_content='Question: Is there on-campus housing available?\nAnswer: Yes, on-campus housing is available for all students.'),
#  Document(metadata={'source': 'The tuition fee for undergraduate programs is $15,000 per year.', 'row': 960}, page_content='Question: What is the tuition fee for undergraduate programs?\nAnswer: The tuition fee for undergraduate programs is $15,000 per year.'),
#  Document(metadata={'source': 'The admission deadline is April 30.', 'row': 961}, page_content='Question: When is the admission deadline?\nAnswer: The admission deadline is April 30.'),
#  Document(metadata={'source': 'Courses include AI, Data Science, and Web Development.', 'row': 962}, page_content='Question: What courses are offered in Computer Science?\nAnswer: Courses include AI, Data Science, and Web Development.'),
#  Document(metadata={'source': 'Yes, international students can apply for financial aid.', 'row': 963}, page_content='Question: Can international students apply for financial aid?\nAnswer: Yes, international students can apply for financial aid.'),
#  Document(metadata={'source': 'Yes, on-campus housing is available for all students.', 'row': 964}, page_content='Question: Is there on-campus housing available?\nAnswer: Yes, on-campus housing is available for all students.'),
#  Document(metadata={'source': 'The tuition fee for undergraduate programs is $15,000 per year.', 'row': 965}, page_content='Question: What is the tuition fee for undergraduate programs?\nAnswer: The tuition fee for undergraduate programs is $15,000 per year.'),
#  Document(metadata={'source': 'The admission deadline is April 30.', 'row': 966}, page_content='Question: When is the admission deadline?\nAnswer: The admission deadline is April 30.'),
#  Document(metadata={'source': 'Courses include AI, Data Science, and Web Development.', 'row': 967}, page_content='Question: What courses are offered in Computer Science?\nAnswer: Courses include AI, Data Science, and Web Development.'),
#  Document(metadata={'source': 'Yes, international students can apply for financial aid.', 'row': 968}, page_content='Question: Can international students apply for financial aid?\nAnswer: Yes, international students can apply for financial aid.'),
#  Document(metadata={'source': 'Yes, on-campus housing is available for all students.', 'row': 969}, page_content='Question: Is there on-campus housing available?\nAnswer: Yes, on-campus housing is available for all students.'),
#  Document(metadata={'source': 'The tuition fee for undergraduate programs is $15,000 per year.', 'row': 970}, page_content='Question: What is the tuition fee for undergraduate programs?\nAnswer: The tuition fee for undergraduate programs is $15,000 per year.'),
#  Document(metadata={'source': 'The admission deadline is April 30.', 'row': 971}, page_content='Question: When is the admission deadline?\nAnswer: The admission deadline is April 30.'),
#  Document(metadata={'source': 'Courses include AI, Data Science, and Web Development.', 'row': 972}, page_content='Question: What courses are offered in Computer Science?\nAnswer: Courses include AI, Data Science, and Web Development.'),
#  Document(metadata={'source': 'Yes, international students can apply for financial aid.', 'row': 973}, page_content='Question: Can international students apply for financial aid?\nAnswer: Yes, international students can apply for financial aid.'),
#  Document(metadata={'source': 'Yes, on-campus housing is available for all students.', 'row': 974}, page_content='Question: Is there on-campus housing available?\nAnswer: Yes, on-campus housing is available for all students.'),
#  Document(metadata={'source': 'The tuition fee for undergraduate programs is $15,000 per year.', 'row': 975}, page_content='Question: What is the tuition fee for undergraduate programs?\nAnswer: The tuition fee for undergraduate programs is $15,000 per year.'),
#  Document(metadata={'source': 'The admission deadline is April 30.', 'row': 976}, page_content='Question: When is the admission deadline?\nAnswer: The admission deadline is April 30.'),
#  Document(metadata={'source': 'Courses include AI, Data Science, and Web Development.', 'row': 977}, page_content='Question: What courses are offered in Computer Science?\nAnswer: Courses include AI, Data Science, and Web Development.'),
#  Document(metadata={'source': 'Yes, international students can apply for financial aid.', 'row': 978}, page_content='Question: Can international students apply for financial aid?\nAnswer: Yes, international students can apply for financial aid.'),
#  Document(metadata={'source': 'Yes, on-campus housing is available for all students.', 'row': 979}, page_content='Question: Is there on-campus housing available?\nAnswer: Yes, on-campus housing is available for all students.'),
#  Document(metadata={'source': 'The tuition fee for undergraduate programs is $15,000 per year.', 'row': 980}, page_content='Question: What is the tuition fee for undergraduate programs?\nAnswer: The tuition fee for undergraduate programs is $15,000 per year.'),
#  Document(metadata={'source': 'The admission deadline is April 30.', 'row': 981}, page_content='Question: When is the admission deadline?\nAnswer: The admission deadline is April 30.'),
#  Document(metadata={'source': 'Courses include AI, Data Science, and Web Development.', 'row': 982}, page_content='Question: What courses are offered in Computer Science?\nAnswer: Courses include AI, Data Science, and Web Development.'),
#  Document(metadata={'source': 'Yes, international students can apply for financial aid.', 'row': 983}, page_content='Question: Can international students apply for financial aid?\nAnswer: Yes, international students can apply for financial aid.'),
#  Document(metadata={'source': 'Yes, on-campus housing is available for all students.', 'row': 984}, page_content='Question: Is there on-campus housing available?\nAnswer: Yes, on-campus housing is available for all students.'),
#  Document(metadata={'source': 'The tuition fee for undergraduate programs is $15,000 per year.', 'row': 985}, page_content='Question: What is the tuition fee for undergraduate programs?\nAnswer: The tuition fee for undergraduate programs is $15,000 per year.'),
#  Document(metadata={'source': 'The admission deadline is April 30.', 'row': 986}, page_content='Question: When is the admission deadline?\nAnswer: The admission deadline is April 30.'),
#  Document(metadata={'source': 'Courses include AI, Data Science, and Web Development.', 'row': 987}, page_content='Question: What courses are offered in Computer Science?\nAnswer: Courses include AI, Data Science, and Web Development.'),
#  Document(metadata={'source': 'Yes, international students can apply for financial aid.', 'row': 988}, page_content='Question: Can international students apply for financial aid?\nAnswer: Yes, international students can apply for financial aid.'),
#  Document(metadata={'source': 'Yes, on-campus housing is available for all students.', 'row': 989}, page_content='Question: Is there on-campus housing available?\nAnswer: Yes, on-campus housing is available for all students.'),
#  Document(metadata={'source': 'The tuition fee for undergraduate programs is $15,000 per year.', 'row': 990}, page_content='Question: What is the tuition fee for undergraduate programs?\nAnswer: The tuition fee for undergraduate programs is $15,000 per year.'),
#  Document(metadata={'source': 'The admission deadline is April 30.', 'row': 991}, page_content='Question: When is the admission deadline?\nAnswer: The admission deadline is April 30.'),
#  Document(metadata={'source': 'Courses include AI, Data Science, and Web Development.', 'row': 992}, page_content='Question: What courses are offered in Computer Science?\nAnswer: Courses include AI, Data Science, and Web Development.'),
#  Document(metadata={'source': 'Yes, international students can apply for financial aid.', 'row':
, page_content='Question: Is there on-campus housing available?\nAnswer: Yes, on-campus housing is available for all students.'),
#  Document(metadata={'source': 'The tuition fee for undergraduate programs is $15,000 per year.', 'row': 995}, page_content='Question: What is the tuition fee for undergraduate programs?\nAnswer: The tuition fee for undergraduate programs is $15,000 per year.'),
#  Document(metadata={'source': 'The admission deadline is April 30.', 'row': 996}, page_content='Question: When is the admission deadline?\nAnswer: The admission deadline is April 30.'),
#  Document(metadata={'source': 'Courses include AI, Data Science, and Web Development.', 'row': 997}, page_content='Question: What courses are offered in Computer Science?\nAnswer: Courses include AI, Data Science, and Web Development.'),
#  Document(metadata={'source': 'Yes, international students can apply for financial aid.', 'row': 998}, page_content='Question: Can international students apply for financial aid?\nAnswer: Yes, international students can apply for financial aid.'),
#  Document(metadata={'source': 'Yes, on-campus housing is available for all students.', 'row': 999}, page_content='Question: Is there on-campus housing available?\nAnswer: Yes, on-campus housing is available for all students.')]

# %%
# Step 4: Initialize Embeddings
embedding_model = GoogleGenerativeAIEmbeddings(google_api_key=key,  model="models/text-embedding-004")

# %%
# Step 5: Create a Chroma Vector Store
vector_store = Chroma.from_documents(documents, embedding=embedding_model)

# %%
llm = ChatGoogleGenerativeAI(google_api_key=key,
                                   model="gemini-1.5-flash")

# %%
retriever = vector_store.as_retriever(search_kwargs={"k": 5})

print(type(retriever))
# Out:
# <class 'langchain_core.vectorstores.base.VectorStoreRetriever'>

# %%
sample_docs = retriever.get_relevant_documents("admission requirements")
for doc in sample_docs:
    print(doc.page_content)
# Out:
# <ipython-input-13-240b9d35c3b0>:1: LangChainDeprecationWarning: The method `BaseRetriever.get_relevant_documents` was deprecated in langchain-core 0.1.46 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   sample_docs = retriever.get_relevant_documents("admission requirements")
# Question: When is the admission deadline?
# Answer: The admission deadline is April 30.
# Question: When is the admission deadline?
# Answer: The admission deadline is April 30.
# Question: When is the admission deadline?
# Answer: The admission deadline is April 30.
# Question: When is the admission deadline?
# Answer: The admission deadline is April 30.
# Question: When is the admission deadline?
# Answer: The admission deadline is April 30.

# %%
from langchain_core.messages import SystemMessage
from langchain_core.prompts import ChatPromptTemplate, HumanMessagePromptTemplate
from langchain_core.runnables import RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser
chat_template = ChatPromptTemplate.from_messages([
    # System Message Prompt Template
    SystemMessage(content="""You are a Helpful Faq Bot.
                  Given a context and question from user,
                  you should answer based on the given context."""),
    # Human Message Prompt Template
    HumanMessagePromptTemplate.from_template("""Answer the question based on the given context.
    Context: {context}
    Question: {question}
    Answer: """)
])

output_parser = StrOutputParser()

def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs)


rag_chain = (
    {"context": retriever | format_docs, "question": RunnablePassthrough()}
    | chat_template
    | llm
    | output_parser
)

# %%
# response = rag_chain.invoke("""Please summarize Leave No Context Behind:
#                             Efficient Infinite Context Transformers with Infini-attention""")

# response

# %%
response = rag_chain.invoke("""What courses are offered in Computer Science?""")

response
# Out:
# 'Courses include AI, Data Science, and Web Development.\n'

# %%
# Step 7: Set Up Retrieval-Augmented Generation (RAG) Chain
from langchain.chains import RetrievalQA
faq_chain = RetrievalQA.from_chain_type(llm=llm, retriever=retriever,chain_type="stuff",)

# %%
# Step 9: Ask a Question
question = "What courses are offered in Computer Science?"
response = faq_chain.run(question)

print("Response:", response)
# Out:
# <ipython-input-18-9b1371ea9825>:3: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   response = faq_chain.run(question)
# Response: Courses include AI, Data Science, and Web Development.
